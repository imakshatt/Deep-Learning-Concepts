# %% [markdown]
# # Image Caption Practical 9

# %% [markdown]
# ## Install necessary packages

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow keras pillow numpy tqdm
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %% [markdown]
# ## import all the necessary packages

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import string
import numpy as np
from PIL import Image
import os
from pickle import dump, load
import numpy as np
import tensorflow
from tensorflow.keras.applications.xception import Xception, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
# from keras.utils import to_categorical
from tensorflow.keras.layers import concatenate
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout

# small library for seeing the progress of loops.
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()
# Out:
# <ipython-input-15-896cb114cd2c>:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   tqdm().pandas()
# 0it [00:00, ?it/s]

# %% [markdown]
# ## Getting and performing data cleaning

# %%
# Loading a text file into memory
def load_doc(filename):
    # Opening the file as read only
    file = open(filename, 'r')
    text = file.read()
    file.close()
    return text

# get all imgs with their captions
def all_img_captions(filename):
    file = load_doc(filename)
    captions = file.split('\n')
    descriptions ={}
    for caption in captions[:-1]:
        img, caption = caption.split('\t')
        if img[:-2] not in descriptions:
            descriptions[img[:-2]] = [ caption ]
        else:
            descriptions[img[:-2]].append(caption)
    return descriptions

#Data cleaning- lower casing, removing puntuations and words containing numbers
def cleaning_text(captions):
    table = str.maketrans('','',string.punctuation)
    for img,caps in captions.items():
        for i,img_caption in enumerate(caps):

            img_caption.replace("-"," ")
            desc = img_caption.split()

            #converts to lowercase
            desc = [word.lower() for word in desc]
            #remove punctuation from each token
            desc = [word.translate(table) for word in desc]
            #remove hanging 's and a
            desc = [word for word in desc if(len(word)>1)]
            #remove tokens with numbers in them
            desc = [word for word in desc if(word.isalpha())]
            #convert back to string

            img_caption = ' '.join(desc)
            captions[img][i]= img_caption
    return captions

def text_vocabulary(descriptions):
    # build vocabulary of all unique words
    vocab = set()

    for key in descriptions.keys():
        [vocab.update(d.split()) for d in descriptions[key]]

    return vocab

#All descriptions in one file
def save_descriptions(descriptions, filename):
    lines = list()
    for key, desc_list in descriptions.items():
        for desc in desc_list:
            lines.append(key + '\t' + desc )
    data = "\n".join(lines)
    file = open(filename,"w")
    file.write(data)
    file.close()

# %%
# dataset_images = "/content/drive/MyDrive/Image_caption/ "
# !unzip "/content/drive/MyDrive/Image_caption/Flicker8k_Dataset.zip" -d "/content/drive/MyDrive/Image_caption/Flicker8k_Dataset"
# Out:
# Archive:  /content/drive/MyDrive/Image_caption/Flickr8k_Dataset.zip
# checkdir:  cannot create extraction directory: /content/drive/MyDrive/Image_caption/Flickr8k_Dataset.zip
#            File exists

# %%
dataset_images = "/content/drive/MyDrive/Image_caption/ "
# !unzip "/content/drive/MyDrive/Image_caption/Flickr8k_Dataset.zip" -d "/content/drive/MyDrive/Image_caption/Flicker8k_Dataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._342872408_04a2832a1b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3429142249_d09a32e291.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3429142249_d09a32e291.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3429194423_98e911a101.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3429194423_98e911a101.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3429351222_17ae744daf.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3429351222_17ae744daf.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3429351964_531de1bf16.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3429351964_531de1bf16.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3429391520_930b153f94.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3429391520_930b153f94.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3429465163_fb8ac7ce7f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3429465163_fb8ac7ce7f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3429581486_4556471d1a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3429581486_4556471d1a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3429641260_2f035c1813.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3429641260_2f035c1813.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3429956016_3c7e3096c2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3429956016_3c7e3096c2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3430100177_5864bf1e73.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3430100177_5864bf1e73.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3430287726_94a1825bbf.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3430287726_94a1825bbf.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3430526230_234b3550f6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3430526230_234b3550f6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3430607596_7e4f74e3ff.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3430607596_7e4f74e3ff.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/343073813_df822aceac.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._343073813_df822aceac.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3430779304_43a2146f4b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3430779304_43a2146f4b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3430782104_34da558eba.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3430782104_34da558eba.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3431101934_99a6c55914.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3431101934_99a6c55914.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3431121650_056db85987.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3431121650_056db85987.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3431194126_ca78f5fde6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3431194126_ca78f5fde6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3431261634_c73360406a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3431261634_c73360406a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3431487300_0123195f9b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3431487300_0123195f9b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3431671749_e8e3a449ac.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3431671749_e8e3a449ac.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3431860810_44277cd360.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3431860810_44277cd360.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/343218198_1ca90e0734.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._343218198_1ca90e0734.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3432495898_a5859f06b6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3432495898_a5859f06b6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3432550415_e7b77232de.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3432550415_e7b77232de.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3432586199_e50b0d6cb7.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3432586199_e50b0d6cb7.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3432634159_1eb9a73306.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3432634159_1eb9a73306.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3432637363_3ba357e2da.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3432637363_3ba357e2da.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3432656291_a6c7981f6e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3432656291_a6c7981f6e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3432730942_4dc4685277.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3432730942_4dc4685277.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3433259846_800a6079f0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3433259846_800a6079f0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3433470650_a8b1c27173.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3433470650_a8b1c27173.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3433567526_00b5a70319.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3433567526_00b5a70319.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3433982387_3fa993cf5a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3433982387_3fa993cf5a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3434452829_62cee280bc.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3434452829_62cee280bc.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3434526008_02359881a0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3434526008_02359881a0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3435015880_eda46ff50f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3435015880_eda46ff50f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3435035138_af32890a4c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3435035138_af32890a4c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3435233065_3411f2d29d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3435233065_3411f2d29d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3435648640_b2f68efb78.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3435648640_b2f68efb78.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3435653630_3b6cca2c40.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3435653630_3b6cca2c40.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3436063693_15c8d377a2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3436063693_15c8d377a2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3436074878_21515a6706.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3436074878_21515a6706.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3436259762_43709321ff.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3436259762_43709321ff.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3436313241_6c73153fb6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3436313241_6c73153fb6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3436395540_63bc8f2fe0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3436395540_63bc8f2fe0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3436418401_b00ceb27c0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3436418401_b00ceb27c0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/343662720_39e4067cd1.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._343662720_39e4067cd1.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3437034427_6df5e9fbf9.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3437034427_6df5e9fbf9.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3437107047_715c60e9c8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3437107047_715c60e9c8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3437147889_4cf26dd525.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3437147889_4cf26dd525.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3437273677_47d4462974.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3437273677_47d4462974.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3437315443_ba2263f92e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3437315443_ba2263f92e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3437654963_c4fdc17e8b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3437654963_c4fdc17e8b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3437693401_202afef348.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3437693401_202afef348.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3437781040_82b06facb3.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3437781040_82b06facb3.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3438858409_136345fa07.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3438858409_136345fa07.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3438981089_2ef1a6353c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3438981089_2ef1a6353c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3439128755_84409b8823.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3439128755_84409b8823.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3439243433_d5f3508612.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3439243433_d5f3508612.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3439331800_e71e1d808f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3439331800_e71e1d808f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3439382048_d2e23b2b4c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3439382048_d2e23b2b4c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3439414478_8038ba9409.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3439414478_8038ba9409.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3439560988_f001f96fc9.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3439560988_f001f96fc9.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3439982121_0afc6d5973.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3439982121_0afc6d5973.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3440104178_6871a24e13.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3440104178_6871a24e13.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3440160917_4524cfd9f6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3440160917_4524cfd9f6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3440724965_03d6ca5399.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3440724965_03d6ca5399.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/344078103_4b23931ce5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._344078103_4b23931ce5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3440952969_608eb5e42b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3440952969_608eb5e42b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3441104823_33cdae5a56.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3441104823_33cdae5a56.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3441145615_b4fcd9eea0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3441145615_b4fcd9eea0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3441399292_60c83bd5db.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3441399292_60c83bd5db.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3441511444_b031585b45.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3441511444_b031585b45.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3441531010_8eebbb507e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3441531010_8eebbb507e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3441701164_6dbbdf1bce.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3441701164_6dbbdf1bce.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3442138291_3e75f4bdb8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3442138291_3e75f4bdb8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3442242092_e579538d82.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3442242092_e579538d82.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3442272060_f9155194c2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3442272060_f9155194c2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3442540072_b22ca2410f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3442540072_b22ca2410f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3442622076_c3abe955e5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3442622076_c3abe955e5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3442844140_15aa45e9b8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3442844140_15aa45e9b8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3442978981_53bf1f45f3.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3442978981_53bf1f45f3.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3443030942_f409586258.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3443030942_f409586258.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3443161359_65544fd732.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3443161359_65544fd732.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3443326696_fe0549c5be.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3443326696_fe0549c5be.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3443351431_7b4061df5c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3443351431_7b4061df5c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3443460885_46115463b4.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3443460885_46115463b4.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3443703471_14845d8850.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3443703471_14845d8850.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3443853670_6c79fcfcb2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3443853670_6c79fcfcb2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3444684583_6656e38088.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3444684583_6656e38088.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3444974984_963fb441a0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3444974984_963fb441a0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3444982197_0ff15cc50b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3444982197_0ff15cc50b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3445296377_1e5082b44b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3445296377_1e5082b44b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3445428367_25bafffe75.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3445428367_25bafffe75.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3445544288_68fdb25969.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3445544288_68fdb25969.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3446191973_1db572ed8a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3446191973_1db572ed8a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3446347599_0ecc49a9d5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3446347599_0ecc49a9d5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3446586125_cafa0bfd67.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3446586125_cafa0bfd67.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3446762868_06e9d9d899.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3446762868_06e9d9d899.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3447007090_08d997833a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3447007090_08d997833a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3447155358_5b5b59b15e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3447155358_5b5b59b15e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3447876218_4ccf42d7a0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3447876218_4ccf42d7a0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/344841963_8b0fa9784c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._344841963_8b0fa9784c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3448490813_f9623e864d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3448490813_f9623e864d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3448855727_f16dea7b03.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3448855727_f16dea7b03.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3449114979_6cdc3e8da8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3449114979_6cdc3e8da8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3449170348_34dac4a380.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3449170348_34dac4a380.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3449718979_e987c64e2d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3449718979_e987c64e2d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3449846784_278bc1ba92.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3449846784_278bc1ba92.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3450776690_38605c667d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3450776690_38605c667d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3450874870_c4dcf58fb3.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3450874870_c4dcf58fb3.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3451085951_e66f7f5d5c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3451085951_e66f7f5d5c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3451344589_6787bd06ef.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3451344589_6787bd06ef.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3451345621_fe470d4cf8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3451345621_fe470d4cf8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3451523035_b61d79f6a8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3451523035_b61d79f6a8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3451984463_37ac1ff7a8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3451984463_37ac1ff7a8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3452127051_fa54a902b3.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3452127051_fa54a902b3.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3452341579_0147d2199b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3452341579_0147d2199b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3452411712_5b42d2a1b5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3452411712_5b42d2a1b5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/345284642_77dded0907.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._345284642_77dded0907.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3452982513_36f2bc81fa.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3452982513_36f2bc81fa.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3453019315_cfd5c10dae.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3453019315_cfd5c10dae.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3453259666_9ecaa8bb4b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3453259666_9ecaa8bb4b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3453284877_8866189055.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3453284877_8866189055.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3453313865_1ebff5393c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3453313865_1ebff5393c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3453544202_3855ab34b6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3453544202_3855ab34b6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3454149297_01454a2554.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3454149297_01454a2554.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3454199170_ae26917dcd.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3454199170_ae26917dcd.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3454315016_f1e30d4676.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3454315016_f1e30d4676.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3454355269_6185e29f95.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3454355269_6185e29f95.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3454621502_73af6742fb.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3454621502_73af6742fb.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3454754632_977c1523be.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3454754632_977c1523be.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3454988449_1de1ef4f20.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3454988449_1de1ef4f20.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3455405300_aa3069ecaa.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3455405300_aa3069ecaa.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3455419642_894d03f153.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3455419642_894d03f153.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3455757720_7aeba57056.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3455757720_7aeba57056.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3455898176_f0e003ce58.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3455898176_f0e003ce58.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3455920874_6fbec43194.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3455920874_6fbec43194.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3456251289_c4ae31d817.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3456251289_c4ae31d817.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3456362961_d8f7e347a8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3456362961_d8f7e347a8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3456579559_b5c8927938.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3456579559_b5c8927938.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/345684566_235e8dfcc1.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._345684566_235e8dfcc1.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3456862740_7550bcddc2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3456862740_7550bcddc2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3457045393_2bbbb4e941.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3457045393_2bbbb4e941.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3457210101_3533edebc8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3457210101_3533edebc8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3457315666_b943111dec.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3457315666_b943111dec.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3457364788_3514a52091.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3457364788_3514a52091.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3457455611_94ee93929f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3457455611_94ee93929f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3457460673_800d7f7dd9.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3457460673_800d7f7dd9.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3457572788_e1fe4f6480.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3457572788_e1fe4f6480.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3457604528_302396c08c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3457604528_302396c08c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3457784061_8f77f43a9c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3457784061_8f77f43a9c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3457856049_2de173e818.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3457856049_2de173e818.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/345785626_9fa59f38ce.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._345785626_9fa59f38ce.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3458211052_bb73084398.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3458211052_bb73084398.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3458215674_2aa5e64643.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3458215674_2aa5e64643.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3458379941_657182bb09.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3458379941_657182bb09.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3458434150_2b0d619244.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3458434150_2b0d619244.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3458559770_12cf9f134e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3458559770_12cf9f134e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3458577912_67db47209d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3458577912_67db47209d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3458625738_297857369c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3458625738_297857369c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3459156091_c1879ebe28.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3459156091_c1879ebe28.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3459362347_c412ef9901.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3459362347_c412ef9901.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3459419203_cd7c68ce4d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3459419203_cd7c68ce4d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3459492423_c881f12c9f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3459492423_c881f12c9f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3459570613_3932816d3f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3459570613_3932816d3f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3459858555_c3f0087a72.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3459858555_c3f0087a72.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3459871361_92d1ecda36.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3459871361_92d1ecda36.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3460458114_35037d4d4c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3460458114_35037d4d4c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3460551728_63255cec18.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3460551728_63255cec18.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3461041826_0e24cdf597.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3461041826_0e24cdf597.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3461049169_e068ae4f25.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3461049169_e068ae4f25.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3461106572_920c8c0112.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3461106572_920c8c0112.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3461110860_37ef15af8e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3461110860_37ef15af8e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3461114418_c27b4043a2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3461114418_c27b4043a2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3461437556_cc5e97f3ac.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3461437556_cc5e97f3ac.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3461583471_2b8b6b4d73.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3461583471_2b8b6b4d73.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3461677493_5bfb73038e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3461677493_5bfb73038e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3462165890_c13ce13eff.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3462165890_c13ce13eff.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3462396164_ba9849c14b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3462396164_ba9849c14b.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3462454965_a481809cea.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3462454965_a481809cea.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3462512074_2b4db1ffd6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3462512074_2b4db1ffd6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/346253487_687150ab04.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._346253487_687150ab04.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3463034205_e541313038.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3463034205_e541313038.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3463268965_f22884fc69.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3463268965_f22884fc69.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3463523977_f2ed231585.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3463523977_f2ed231585.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3463922449_f6040a2931.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3463922449_f6040a2931.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3464708890_3cab754998.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3464708890_3cab754998.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3464871350_3f2d624a9c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3464871350_3f2d624a9c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3465000218_c94e54e208.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3465000218_c94e54e208.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3465396606_5ba1574128.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3465396606_5ba1574128.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3465473743_7da0c5d973.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3465473743_7da0c5d973.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3465606652_f380a38050.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3465606652_f380a38050.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3465791729_5bf9bd8635.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3465791729_5bf9bd8635.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3466353172_deb128bbb0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3466353172_deb128bbb0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3466891862_9afde75568.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3466891862_9afde75568.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3467073304_aefe553c4d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3467073304_aefe553c4d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/3467219837_7d62213dec.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._3467219837_7d62213dec.jpg
# ...
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/933118213_b35b0b62a7.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._933118213_b35b0b62a7.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/934375844_dd149fed18.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._934375844_dd149fed18.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/937559727_ae2613cee5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._937559727_ae2613cee5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/938162709_21443d352f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._938162709_21443d352f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/93922153_8d831f7f01.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._93922153_8d831f7f01.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/940973925_a2e6d7951c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._940973925_a2e6d7951c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/94232465_a135df2711.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._94232465_a135df2711.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/942399470_6132d3e5d2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._942399470_6132d3e5d2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/944374205_fd3e69bfca.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._944374205_fd3e69bfca.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/944788251_a0bcd4b960.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._944788251_a0bcd4b960.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/945509052_740bb19bc3.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._945509052_740bb19bc3.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/946051430_8db7e4ce09.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._946051430_8db7e4ce09.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/947664583_7c63172366.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._947664583_7c63172366.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/947969010_f1ea572e89.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._947969010_f1ea572e89.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/948196883_e190a483b1.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._948196883_e190a483b1.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/950273886_88c324e663.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._950273886_88c324e663.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/950411653_20d0335946.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._950411653_20d0335946.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/95151149_5ca6747df6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._95151149_5ca6747df6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/952171414_2db16f846f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._952171414_2db16f846f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/953941506_5082c9160c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._953941506_5082c9160c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/954987350_a0c608b467.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._954987350_a0c608b467.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/956164675_9ee084364e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._956164675_9ee084364e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/957230475_48f4285ffe.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._957230475_48f4285ffe.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/95728660_d47de66544.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._95728660_d47de66544.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/95728664_06c43b90f1.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._95728664_06c43b90f1.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/95734035_84732a92c1.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._95734035_84732a92c1.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/95734036_bef6d1a871.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._95734036_bef6d1a871.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/95734038_2ab5783da7.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._95734038_2ab5783da7.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/957682378_46c3b07bcd.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._957682378_46c3b07bcd.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/95783195_e1ba3f57ca.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._95783195_e1ba3f57ca.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/958326692_6210150354.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._958326692_6210150354.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/961189263_0990f3bcb5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._961189263_0990f3bcb5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/961611340_251081fcb8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._961611340_251081fcb8.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/963730324_0638534227.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._963730324_0638534227.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/96399948_b86c61bfe6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._96399948_b86c61bfe6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/964197865_0133acaeb4.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._964197865_0133acaeb4.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/96420612_feb18fc6c6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._96420612_feb18fc6c6.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/965444691_fe7e85bf0e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._965444691_fe7e85bf0e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/967719295_3257695095.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._967719295_3257695095.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/968081289_cdba83ce2e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._968081289_cdba83ce2e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/96973080_783e375945.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._96973080_783e375945.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/96978713_775d66a18d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._96978713_775d66a18d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/96985174_31d4c6f06d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._96985174_31d4c6f06d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/970641406_9a20ee636a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._970641406_9a20ee636a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/97105139_fae46fe8ef.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._97105139_fae46fe8ef.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/972381743_5677b420ab.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._972381743_5677b420ab.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/973827791_467d83986e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._973827791_467d83986e.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/97406261_5eea044056.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._97406261_5eea044056.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/974924582_10bed89b8d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._974924582_10bed89b8d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/975131015_9acd25db9c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._975131015_9acd25db9c.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/97577988_65e2eae14a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._97577988_65e2eae14a.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/976392326_082dafc3c5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._976392326_082dafc3c5.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/97731718_eb7ba71fd3.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._97731718_eb7ba71fd3.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/977856234_0d9caee7b2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._977856234_0d9caee7b2.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/978580450_e862715aba.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._978580450_e862715aba.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/979201222_75b6456d34.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._979201222_75b6456d34.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/979383193_0a542a059d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._979383193_0a542a059d.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/98377566_e4674d1ebd.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._98377566_e4674d1ebd.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/985067019_705fe4a4cc.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._985067019_705fe4a4cc.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/987907964_5a06a63609.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._987907964_5a06a63609.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/989754491_7e53fb4586.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._989754491_7e53fb4586.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/989851184_9ef368e520.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._989851184_9ef368e520.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/990890291_afc72be141.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._990890291_afc72be141.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/99171998_7cc800ceef.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._99171998_7cc800ceef.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/99679241_adc853a5c0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._99679241_adc853a5c0.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/997338199_7343367d7f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._997338199_7343367d7f.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/997722733_0cb5439472.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/Flicker8k_Dataset/._997722733_0cb5439472.jpg
#   inflating: /content/drive/MyDrive/Image_caption/Flicker8k_Dataset/__MACOSX/._Flicker8k_Dataset

# %%
# Set these path according to project folder in you system
# dataset_text = "/content/drive/MyDrive/Image_Caption/Flickr8k_text"
dataset_images = "/content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset"

#we prepare our text data
filename = "/content/drive/MyDrive/Image_caption/Flickr8k.token.txt"
#loading the file that contains all data
#mapping them into descriptions dictionary img to 5 captions
descriptions = all_img_captions(filename)
print("Length of descriptions =" , len(descriptions))

#cleaning the descriptions
clean_descriptions = cleaning_text(descriptions)

#building vocabulary
vocabulary = text_vocabulary(clean_descriptions)
print("Length of vocabulary = ", len(vocabulary))

#saving each description to file

save_descriptions(clean_descriptions, "/content/drive/MyDrive/Image_caption/descriptions.txt")
# Out:
# Length of descriptions = 8092
# Length of vocabulary =  8763

# %% [markdown]
# ## Extracting the feature vector from all images

# %%
def extract_features(directory):
        model = Xception( include_top=False, pooling='avg' )
        features = {}
        for img in tqdm(os.listdir(directory)):
            filename = directory + "/" + img
            image = Image.open(filename)
            image = image.resize((299,299))
            image = np.expand_dims(image, axis=0)
            #image = preprocess_input(image)
            image = image/127.5
            image = image - 1.0

            feature = model.predict(image)
            features[img] = feature
        return features

#2048 feature vector
features = extract_features(dataset_images)
dump(features, open("/content/drive/MyDrive/Image_caption/features.p","wb"))

import pickle

# Extract features
features = extract_features(dataset_images)

# Save features to a file
with open('/content/drive/MyDrive/Image_caption/features.pkl', 'wb') as f:
    pickle.dump(features, f)
# Out:
# <ipython-input-25-2c786713e5f0>:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for img in tqdm(os.listdir(directory)):
#   0%|          | 0/8091 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# ...
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step

# %%
import pickle

# Load features from file
with open('/content/drive/MyDrive/Image_caption/features.pkl', 'rb') as f:
    features = pickle.load(f)

# %%
features = load(open("/content/drive/MyDrive/Image_caption/features.pkl","rb"))

# %% [markdown]
# ## Loading dataset for Training the model

# %%
#load the data
def load_photos(filename):
    file = load_doc(filename)
    photos = file.split("\n")[:-1]
    return photos


def load_clean_descriptions(filename, photos):
    #loading clean_descriptions
    file = load_doc(filename)
    descriptions = {}
    for line in file.split("\n"):

        words = line.split()
        if len(words)<1 :
            continue

        image, image_caption = words[0], words[1:]

        if image in photos:
            if image not in descriptions:
                descriptions[image] = []
            desc = '<start> ' + " ".join(image_caption) + ' <end>'
            descriptions[image].append(desc)

    return descriptions


def load_features(photos):
    #loading all features
    all_features = load(open("/content/drive/MyDrive/Image_caption/features.pkl","rb"))
    #selecting only needed features
    features = {k:all_features[k] for k in photos}
    return features


filename = dataset_text + "/" + "Flickr_8k.trainImages.txt"

#train = loading_data(filename)
train_imgs = load_photos(filename)
train_descriptions = load_clean_descriptions("/content/drive/MyDrive/Image_caption/descriptions.txt", train_imgs)
train_features = load_features(train_imgs)

# %% [markdown]
# ## Tokenizing the vocabulary

# %%
#converting dictionary to clean list of descriptions
def dict_to_list(descriptions):
    all_desc = []
    for key in descriptions.keys():
        [all_desc.append(d) for d in descriptions[key]]
    return all_desc

#creating tokenizer class
#this will vectorise text corpus
#each integer will represent token in dictionary

from keras.preprocessing.text import Tokenizer

def create_tokenizer(descriptions):
    desc_list = dict_to_list(descriptions)
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(desc_list)
    return tokenizer

# give each word an index, and store that into tokenizer.p pickle file
tokenizer = create_tokenizer(train_descriptions)
dump(tokenizer, open('/content/drive/MyDrive/Image_caption/tokenizer.p', 'wb'))
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 7577

# %%
#calculate maximum length of descriptions
def max_length(descriptions):
    desc_list = dict_to_list(descriptions)
    return max(len(d.split()) for d in desc_list)

max_length = max_length(descriptions)
max_length
# Out:
# 32

# %% [markdown]
# ##  Create Data generator

# %%
#create input-output sequence pairs from the image description.

#data generator, used by model.fit_generator()
def data_generator(descriptions, features, tokenizer, max_length):
    while 1:
        for key, description_list in descriptions.items():
            #retrieve photo features
            feature = features[key][0]
            input_image, input_sequence, output_word = create_sequences(tokenizer, max_length, description_list, feature)
            yield ([input_image, input_sequence], output_word)

def create_sequences(tokenizer, max_length, desc_list, feature):
    X1, X2, y = list(), list(), list()
    # walk through each description for the image
    for desc in desc_list:
        # encode the sequence
        seq = tokenizer.texts_to_sequences([desc])[0]
        # split one sequence into multiple X,y pairs
        for i in range(1, len(seq)):
            # split into input and output pair
            in_seq, out_seq = seq[:i], seq[i]
            # pad input sequence
            in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
            # encode output sequence
            out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
            # store
            X1.append(feature)
            X2.append(in_seq)
            y.append(out_seq)
    return np.array(X1), np.array(X2), np.array(y)

#You can check the shape of the input and output for your model
[a,b],c = next(data_generator(train_descriptions, features, tokenizer, max_length))
a.shape, b.shape, c.shape
#((47, 2048), (47, 32), (47, 7577))
# Out:
# ((47, 2048), (47, 32), (47, 7577))

# %% [markdown]
# ## Defining the CNN-RNN model

# %%
from tensorflow.keras.utils import plot_model

# define the captioning model
def define_model(vocab_size, max_length):

    # features from the CNN model squeezed from 2048 to 256 nodes
    inputs1 = Input(shape=(2048,))
    fe1 = Dropout(0.5)(inputs1)
    fe2 = Dense(256, activation='relu')(fe1)

    # LSTM sequence model
    inputs2 = Input(shape=(max_length,))
    se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
    se2 = Dropout(0.5)(se1)
    se3 = LSTM(256)(se2)

    # Merging both models
    decoder1 = concatenate([fe2, se3])
    decoder2 = Dense(256, activation='relu')(decoder1)
    outputs = Dense(vocab_size, activation='softmax')(decoder2)

    # tie it together [image, seq] [word]
    model = Model(inputs=[inputs1, inputs2], outputs=outputs)
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    # summarize model
    print(model.summary())
    plot_model(model, to_file='/content/drive/MyDrive/Image_caption/model.png', show_shapes=True)

    return model

# %% [markdown]
# ## TRAINING SECTION

# %%
# train our model
print('Dataset: ', len(train_imgs))
print('Descriptions: train=', len(train_descriptions))
print('Photos: train=', len(train_features))
print('Vocabulary Size:', vocab_size)
print('Description Length: ', max_length)

model = define_model(vocab_size, max_length)
print(model,'model')
epochs = 1
steps = len(train_descriptions)
# making a directory models to save our models
#os.mkdir("/content/drive/MyDrive/Image_Caption/models")
for i in range(epochs):
    generator = data_generator(train_descriptions, train_features, tokenizer, max_length)
    model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
    model.save("/content/drive/MyDrive/Image_caption/models/models_" + str(i) + ".h5")
# Out:
# Dataset:  6000
# Descriptions: train= 6000
# Photos: train= 6000
# Vocabulary Size: 7577
# Description Length:  32
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 32)]         0           []
#
#  input_3 (InputLayer)           [(None, 2048)]       0           []
#
#  embedding_1 (Embedding)        (None, 32, 256)      1939712     ['input_4[0][0]']
#
#  dropout_2 (Dropout)            (None, 2048)         0           ['input_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 32, 256)      0           ['embedding_1[0][0]']
#
#  dense_3 (Dense)                (None, 256)          524544      ['dropout_2[0][0]']
#
#  lstm_1 (LSTM)                  (None, 256)          525312      ['dropout_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 512)          0           ['dense_3[0][0]',
#                                                                   'lstm_1[0][0]']
#
#  dense_4 (Dense)                (None, 256)          131328      ['concatenate_1[0][0]']
#
#  dense_5 (Dense)                (None, 7577)         1947289     ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 5,068,185
# Trainable params: 5,068,185
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# <keras.engine.functional.Functional object at 0x7f4eaa573e80> model
# <ipython-input-27-69b5557fc281>:16: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
# 6000/6000 [==============================] - 724s 120ms/step - loss: 4.5037

# %% [markdown]
# # TEST THE MODEL USING DUMY FOLLOWING IMAGE AND CODE

# %%
from PIL import Image
img = Image.open('/content/drive/MyDrive/Image_Caption/Flicker8k_Dataset/1028205764_7e8df9a2ea.jpg')
#imagePath = '/content/drive/MyDrive/Image_caption/Flicker8k_Dataset/Flicker8k_Dataset/1022454428_b6b660a67b.jpg'
# img = Image.open(imagePath)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x292>

# %%
# !python3 '/content/drive/MyDrive/Image_Caption/testing_caption_generator (1).py' -i '/content/drive/MyDrive/Image_Caption/Flicker8k_Dataset/1028205764_7e8df9a2ea.jpg'
# !python3 '/content/drive/MyDrive/ML/testing_caption_generator.py' -i '/content/drive/MyDrive/ML/Flicker8k_Dataset/3738685861_8dfff28760.jpg'
# Out:
# 2024-03-18 09:30:45.132431: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-18 09:30:45.132485: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-18 09:30:45.133645: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-18 09:30:46.270818: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-18 09:30:49.674555: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 1/1 [==============================] - 2s 2s/step
#
#
#
# start kayaker is pulled on boat in the water end
